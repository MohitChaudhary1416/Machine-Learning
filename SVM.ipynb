# %% [markdown]
# ## Support Vector Machines

# %%
import pandas as pd
from sklearn.svm import SVC 
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
from sklearn.datasets import make_blobs

# %%
X,y = make_blobs(n_samples = 200, n_features = 2, centers = 2, cluster_std = 0.15, random_state = 5 )

# %%
x_df = pd.DataFrame(X, columns = ['A', 'B']) # Changing array into dataframe
x_df
# Out:
#             A         B
# 0   -5.616480  7.201357
# 1   -5.948041  8.427881
# 2   -5.576211  7.753662
# 3   -5.657090  7.496931
# 4   -5.349812  7.484411
# ..        ...       ...
# 195 -5.763055  8.496155
# 196 -5.809245  8.338321
# 197 -5.903037  8.264617
# 198 -6.033810  8.593145
# 199 -5.569039  7.056641
#
# [200 rows x 2 columns]

# %%
import seaborn as sns

# %%
sns.scatterplot(data = x_df, x = 'A', y = 'B' ,hue = y)
plt.show()

# %%
xtrain,xtest,ytrain,ytest = train_test_split(x_df,y,test_size = 0.2, random_state = 7)

# %%
svm = SVC()
svm.fit(xtrain,ytrain)
# Out:
# SVC()

# %%
kernal - linear,rbf, sigmoid,polynomial

# %%
pip install mlxtend
# Out:
# ...
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    --------------- ------------------------ 0.5/1.4 MB 3.3 MB/s eta 0:00:01
#    ---------------------------------------- 1.4/1.4 MB 4.4 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from mlxtend.plotting import plot_decision_regions

# %%
plot_decision_regions(X = X, y=y, clf = svm)
# Out:
# C:\Users\Mohit Chaudhary\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# <Axes: >

# %%
# Non Seperatly data using SVM

# %%
from sklearn.datasets import make_circles

# %%
X, y = make_circles(200,noise=0.05,random_state = 5)

# %%
x_df = pd.DataFrame(X, columns = ['A','B'])
x_df
# Out:
#             A         B
# 0    0.281569  0.735784
# 1    0.101872 -0.970217
# 2   -0.767544  0.074949
# 3   -0.780119  0.113775
# 4   -0.771138 -0.174524
# ..        ...       ...
# 195 -0.183841 -0.932510
# 196 -0.836622  0.298660
# 197  0.252860  0.658983
# 198  0.578092 -0.502348
# 199  1.035505 -0.093072
#
# [200 rows x 2 columns]

# %%
sns.scatterplot(data = x_df, x = 'A', y = 'B', hue = y)
plt.show()

# %%
xtrain,xtest,ytrain,ytest = train_test_split(x_df, y ,test_size = 0.2, random_state = 7)

# %%
svm = SVC(kernel ='rbf')
svm.fit(xtrain,ytrain)
# Out:
# SVC()

# %%
plot_decision_regions(X = X, y =y , clf = svm)
# Out:
# C:\Users\Mohit Chaudhary\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# <Axes: >

# %%
ypred = svm.predict(xtest)

# %%
accuracy = accuracy_score(ytest,ypred)
print(f'ACCURACY = {accuracy:.2%}')
# Out:
# ACCURACY = 100.00%
